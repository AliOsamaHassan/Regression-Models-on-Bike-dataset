# %%
from sklearn.linear_model import Ridge,LogisticRegression
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score,KFold,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn import linear_model
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix,classification_report,roc_auc_score
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn import cross_validation
import seaborn as sns
#%matplotlib

# %% [markdown]
# #  Initialize Random Number Generator
#
# Next, we need to initialize the random number generator to a constant value (7).
#
# This is important to ensure that the results we achieve from this model can be achieved again precisely. It ensures that the stochastic process of training a neural network model can be reproduced.

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# %% [markdown]
# # Loading data

# %%
train_data = pd.read_csv('reg_train.csv')
test_data = pd.read_csv('reg_test.csv')

# %%
print(len(train_data.columns))
train_data.head()
# Out:
# 17
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
print(len(test_data.columns))
test_data.head()
# Out:
# 14
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0    13904  2012-08-07       3   1     8  12        0        2           1
# 1    13905  2012-08-07       3   1     8  13        0        2           1
# 2    13906  2012-08-07       3   1     8  14        0        2           1
# 3    13907  2012-08-07       3   1     8  15        0        2           1
# 4    13908  2012-08-07       3   1     8  16        0        2           1
#
#    weathersit  temp   atemp   hum  windspeed
# 0           2  0.80  0.7576  0.55     0.1343
# 1           2  0.80  0.7424  0.52     0.1940
# 2           2  0.82  0.7576  0.46     0.0000
# 3           1  0.80  0.7424  0.52     0.0000
# 4           3  0.76  0.7273  0.66     0.2836

# %% [markdown]
# ## Converting date variable into numerical value

# %%
train_data['dteday'] = pd.to_datetime(train_data['dteday']).map(dt.datetime.toordinal)
#train_data['dteday']=train_data['dteday'].map(dt.datetime.toordinal)
test_data['dteday'] = pd.to_datetime(test_data['dteday']).map(dt.datetime.toordinal)
#test_data['dteday']=test_data['dteday'].map(dt.datetime.toordinal)

# %%
#X_features =['season','yr','mnth','hr','holiday','weekday','workingday','weathersit','temp','atemp','hum','windspeed','casual','registered']
X_features =['season','yr','mnth','hr','holiday','weekday','workingday','weathersit','temp','atemp','hum','windspeed']
y_features = ['cnt']
print(len(X_features),len(y_features))
# Out:
# 12 1

# %%
X = train_data[X_features]
y = train_data[y_features]
X_pred = test_data[X_features]

# %% [markdown]
# # Histogram plots
#
# A fast way to get an idea of the distribution of each attribute is to look at histograms.
#
# Histograms group data into bins and provide you a count of the number of observations in each bin. From the shape of the bins you can quickly get a feeling for whether an attribute is Gaussian’, skewed or even has an exponential distribution. It can also help you see possible outliers.

# %%
X.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# # Density Plots
#
# Density plots are another way of getting a quick idea of the distribution of each attribute. The plots look like an abstracted histogram with a smooth curve drawn through the top of each bin, much like your eye tried to do with the histograms.

# %%
X.plot(kind='density', subplots=True, layout=(4,4), sharex=False,figsize=(20,20))
plt.show()

# %% [markdown]
# # Box and Whisker Plots
# Another useful way to review the distribution of each attribute is to use Box and Whisker Plots or boxplots for short.
#
# Boxplots summarize the distribution of each attribute, drawing a line for the median (middle value) and a box around the 25th and 75th percentiles (the middle 50% of the data). The whiskers give an idea of the spread of the data and dots outside of the whiskers show candidate outlier values (values that are 1.5 times greater than the size of spread of the middle 50% of the data).

# %%
X.plot(kind='box', subplots=True, layout=(4,4), sharex=False,figsize=(20,20), sharey=False)
plt.show()

# %% [markdown]
# # Correlation Matrix Plot
#
# Correlation gives an indication of how related the changes are between two variables. If two variables change in the same direction they are positively correlated. If the change in opposite directions together (one goes up, one goes down), then they are negatively correlated.
#
# You can calculate the correlation between each pair of attributes. This is called a correlation matrix. You can then plot the correlation matrix and get an idea of which variables have a high correlation with each other.
#
# This is useful to know, because some machine learning algorithms like linear and logistic regression can have poor performance if there are highly correlated input variables in your data.

# %%
correlations = X.corr()
# plot correlation matrix
fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,len(X_features),1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(X_features)
ax.set_yticklabels(X_features)
plt.show()

# %% [markdown]
# We can see that the matrix is symmetrical, i.e. the bottom left of the matrix is the same as the top right. This is useful as we can see two different views on the same data in one plot. We can also see that each variable is perfectly positively correlated with each other (as you would expected) in the diagonal line from top left to bottom right.

# %% [markdown]
# # Scatterplot Matrix
# A scatterplot shows the relationship between two variables as dots in two dimensions, one axis for each attribute. You can create a scatterplot for each pair of attributes in your data. Drawing all these scatterplots together is called a scatterplot matrix.
#
# Scatter plots are useful for spotting structured relationships between variables, like whether you could summarize the relationship between two variables with a line. Attributes with structured relationships may also be correlated and good candidates for removal from your dataset.

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(X,figsize=(15,15))
plt.show()

# %% [markdown]
# # Visualizing pairwise relationships

# %%
sns.pairplot(X)

# %% [markdown]
# # Splitting data

# %%
X_features =['temp','atemp','hum','windspeed']
y_features = ['cnt']
X = train_data[X_features]
y = train_data[y_features]
X_pred = test_data[X_features]
# split into input (X) and output (Y) variables
test_size_param = 0.2
X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size=test_size_param,random_state=0)

# %%
#X_train.head()
print(X_train.shape)
print(Y_train.shape)

print(X_test.shape)
print(Y_test.shape)
# Out:
# (11122, 4)
# (11122, 1)
# (2781, 4)
# (2781, 1)

# %%
Y_train.head()
# Out:
#        cnt
# 9086   111
# 1832     1
# 7733    68
# 11765  154
# 12779  320

# %% [markdown]
# # Linear Regression Model

# %%
regressor = linear_model.LinearRegression()

# %%
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
regressor.intercept_
# Out:
# array([129.89378215])

# %%
#The coefficients
print('Coefficients: ',regressor.coef_)
#The mean square error
print('Mean Square Error: ', numpy.mean((regressor.predict(X_test)-Y_test)**2))
# Explained Variance score : 1 is perfect prediction
print('Variance score: ',regressor.score(X_test,Y_test))
# Out:
# Coefficients:  [[  37.56684928  349.4780631  -244.50623724   57.20881044]]
# Mean Square Error:  cnt    20488.094331
# dtype: float64
# Variance score:  0.2795891155041471

# %%
regressor.coef_[0].tolist()
# Out:
# [37.566849275937955, 349.4780630978997, -244.50623723658666, 57.20881043643665]

# %%
zipped = zip(X_features,regressor.coef_[0].tolist())
pd.DataFrame(list(zipped),columns=["Features","Coefficients"])
# Out:
#     Features  Coefficients
# 0       temp     37.566849
# 1      atemp    349.478063
# 2        hum   -244.506237
# 3  windspeed     57.208810

# %%
y_pred = regressor.predict(X_pred)
y_pred
print((y_pred[:,0]))
my_submission = pd.DataFrame({'instant': test_data.instant, 'cnt': y_pred[:,0]})
my_submission.to_csv('submission.csv',index = False)
# Out:
# [297.91655494 303.35504148 312.99031003 ...  92.37665635 105.72348116
#   83.71791981]

# %% [markdown]
# # Scatter plot for the predicted x_test and y_test values

# %%
plt.scatter(regressor.predict(X_test),Y_test)
plt.show()

# %% [markdown]
# # Random Forest Model

# %%
my_model = RandomForestRegressor()
my_model.fit(X_train, Y_train)
# Out:
# C:\Users\Ali\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
# Use the model to make predictions
y_pred2 = my_model.predict(X_test)
# We will look at the predicted prices to ensure we have something sensible.
print(y_pred2)
# Out:
# [123.90099567  10.34714286 322.68333333 ...  43.36333333 240.06666667
#   27.7       ]

# %%
print(y_pred2)
my_submission = pd.DataFrame({'instant': test_data.instant, 'cnt': y_pred2[:,0]})
my_submission.to_csv('submission.csv',index = False)
# Out:
# [123.90099567  10.34714286 322.68333333 ...  43.36333333 240.06666667
#   27.7       ]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-155-58f93527161b> in <module>()
#       1 print(y_pred2)
# ----> 2 my_submission = pd.DataFrame({'instant': test_data.instant, 'cnt': y_pred2[:,0]})
#       3 my_submission.to_csv('submission.csv',index = False)
#
# IndexError: too many indices for array

# %% [markdown]
# # Program Parameters

# %%
validation_split_param = 0.1
num_layers_hidden = 10
activation_output_function = 'softmax'
loss_function_param='mean_squared_error'
n_units = 50
epochs_param = 30
batch_size_param = 16

# %% [markdown]
# # Develop a Neural Network Model¶

# %%
def model():
    # create model
    model = Sequential()
    # Adding the input layer
    model.add(Dense(n_units, input_dim=len(X_features), kernel_initializer='normal', activation='relu'))
    # Adding hidden layers
    for _ in range(num_layers_hidden-1):
        model.add(Dense(n_units,kernel_initializer='normal', activation='relu'))
    # Adding the output layer
    model.add(Dense(1,activation=activation_output_function, kernel_initializer='normal'))    
    # Compile model
    model.compile(loss=loss_function_param, optimizer='adam',metrics=['accuracy'])
    print(model.summary())
    return model

# %%
model = model()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 50)                250
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_4 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_6 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                2550
# ...

# %%
model.fit(X_train,Y_train,epochs=epochs_param,
          validation_data=(X_test,Y_test),
          batch_size=batch_size_param,verbose=1)
# Out:
# Train on 11122 samples, validate on 2781 samples
# Epoch 1/30
# 11122/11122 [==============================] - 2s 199us/step - loss: 57727.0635 - acc: 0.0102 - val_loss: 59204.8188 - val_acc: 0.0129
# Epoch 2/30
# 11122/11122 [==============================] - 1s 113us/step - loss: 57727.0635 - acc: 0.0102 - val_loss: 59204.8188 - val_acc: 0.0129
# Epoch 3/30
# 11122/11122 [==============================] - 1s 115us/step - loss: 57727.0635 - acc: 0.0102 - val_loss: 59204.8188 - val_acc: 0.0129
# Epoch 4/30
# 11122/11122 [==============================] - 1s 116us/step - loss: 57727.0635 - acc: 0.0102 - val_loss: 59204.8188 - val_acc: 0.0129
# Epoch 5/30
# 11122/11122 [==============================] - 1s 117us/step - loss: 57727.0635 - acc: 0.0102 - val_loss: 59204.8188 - val_acc: 0.0129
# Epoch 6/30
# 11122/11122 [==============================] - 1s 117us/step - loss: 57727.0635 - acc: 0.0102 - val_loss: 59204.8188 - val_acc: 0.0129
# Epoch 7/30
# ...

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# evaluate model with standardized dataset
estimator = KerasRegressor(build_fn=model(), epochs=epochs_param, batch_size=batch_size_param, verbose=1)

# %%
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(estimator, X_train, Y_train, cv=kfold )
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-cbded7cee79b> in <module>()
#       1 kfold = KFold(n_splits=10, random_state=seed)
# ----> 2 results = cross_val_score(estimator, X_train, Y_train, cv=kfold )
#       3 print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
#
# C:\Users\Ali\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     340                                 n_jobs=n_jobs, verbose=verbose,
#     341                                 fit_params=fit_params,
# --> 342                                 pre_dispatch=pre_dispatch)
#     343     return cv_results['test_score']
#     344
#
# ...

# %% [markdown]
# # Modeling The Standardized Dataset

# %%
# evaluate model with standardized dataset
numpy.random.seed(seed)
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasRegressor(build_fn=model, epochs=epochs_param, batch_size=batch_size_param, verbose=0)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(pipeline, X_train, Y_train, cv=kfold )
print("Standardized: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Standardized: -0.51 (0.75) MSE

# %% [markdown]
# # Evaluate model

# %%
estimator.fit(X, y)
# Final evaluation of the model
#scores = estimator.evaluate(X_test, Y_test, verbose=1)
print("Accuracy: %.2f%%" % (-1*results[1]*100))
# Out:
# Accuracy: 6.07%

# %% [markdown]
# # GridSearchCV Evaluating

# %%
# define the grid search parameters
batch_size = [10, 20, 40, 60, 80, 100]
epochs = [10, 50, 100]
#optimizer = ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']
param_grid = dict(batch_size=batch_size, epochs=epochs)
grid = GridSearchCV(estimator=estimator, param_grid=param_grid, n_jobs=-1)
grid_result = grid.fit(X,y)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# %% [markdown]
# # Predicting and preparing the submission file

# %%
import numpy as np
lr = linear_model.LinearRegression()
scores = cross_validation.cross_val_score(lr, X_train, Y_train)
print("LR score:\t %0.3f" % scores.mean() )

lrf = lr.fit(X_train, Y_train)
score = lrf.score(X_train, Y_train)
print("LR.score():\t  %0.3f" % score )
print(test_data.columns[1:])
y_pred= lrf.predict(test_data[test_data.columns[1:]])
print(y_pred.shape)


submission = pd.DataFrame({
    
    "cnt":y_pred
})

submission.to_csv("submission.csv",index=False)
# Out:
# LR score:	 1.000
# LR.score():	  1.000
# Index(['season', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-3f7c396401fc> in <module>()
#       8 print("LR.score():\t  %0.3f" % score )
#       9 print(test_data.columns[1:])
# ---> 10 y_pred= lrf.predict(test_data[test_data.columns[1:]])
#      11 print(y_pred.shape)
#      12
#
# C:\Users\Ali\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     254             Returns predicted values.
#     255         """
# --> 256         return self._decision_function(X)
#     257
#     258     _preprocess_data = staticmethod(_preprocess_data)
#
# C:\Users\Ali\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
# ...
